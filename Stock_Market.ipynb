# %% [markdown]
# <a href="https://colab.research.google.com/github/purirajan/Colab/blob/main/Stock_Market.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance==0.1.67
#!pip install pandas==1.3.3
# Out:
# ...
#      |████████████████████████████████| 6.4 MB 13.5 MB/s
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
apple = yf.Ticker("AAPL")
apple_info=apple.info
apple_info
# Out:
# {'52WeekChange': 0.405779,
#  'SandP52WeekChange': 0.16005337,
#  'address1': 'One Apple Park Way',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 170.52,
#  'askSize': 1200,
#  'averageDailyVolume10Day': 97387620,
#  'averageVolume': 93351350,
#  'averageVolume10days': 97387620,
#  'beta': 1.185531,
#  'beta3Year': None,
#  'bid': 170.5,
#  'bidSize': 1000,
#  'bookValue': 4.402,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Cupertino',
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 170.21,
#  'currentRatio': 1.038,
#  'dateShortInterest': 1646006400,
#  'dayHigh': 172.64,
#  'dayLow': 167.65,
#  'debtToEquity': 170.714,
#  'dividendRate': 0.88,
#  'dividendYield': 0.0052,
#  'earningsGrowth': 0.25,
#  'earningsQuarterlyGrowth': 0.204,
#  'ebitda': 128217997312,
#  'ebitdaMargins': 0.33890998,
#  'enterpriseToEbitda': 21.946,
#  'enterpriseToRevenue': 7.438,
# ...

# %%
apple_info['country']
# Out:
# 'United States'

# %%
apple_share_price_data = apple.history(period="max")

# %%
apple_share_price_data.tail()
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2022-03-17  158.610001  161.000000  157.630005  160.619995   75615400
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  123351200
# 2022-03-21  163.509995  166.350006  163.009995  165.380005   95811400
# 2022-03-22  165.509995  169.419998  164.910004  168.820007   81532000
# 2022-03-23  167.990005  172.639999  167.649994  170.210007   98062674
#
#             Dividends  Stock Splits
# Date
# 2022-03-17        0.0           0.0
# 2022-03-18        0.0           0.0
# 2022-03-21        0.0           0.0
# 2022-03-22        0.0           0.0
# 2022-03-23        0.0           0.0

# %%
apple_share_price_data.reset_index(inplace=True)

# %%
apple_share_price_data.plot(x="Date", y="Open")

# %%
apple.dividends
# Out:
# Date
# 1987-05-11    0.000536
# 1987-08-10    0.000536
# 1987-11-17    0.000714
# 1988-02-12    0.000714
# 1988-05-16    0.000714
#                 ...
# 2021-02-05    0.205000
# 2021-05-07    0.220000
# 2021-08-06    0.220000
# 2021-11-05    0.220000
# 2022-02-04    0.220000
# Name: Dividends, Length: 74, dtype: float64

# %%
apple.dividends.plot()

# %%
clover = yf.Ticker("CLOV")
clover_info=clover.info
clover_info
# Out:
# {'52WeekChange': -0.5371578,
#  'SandP52WeekChange': 0.16005337,
#  'address1': '725 Cool Springs Blvd',
#  'address2': 'Suite 300',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 3.82,
#  'askSize': 28000,
#  'averageDailyVolume10Day': 14767670,
#  'averageVolume': 15891541,
#  'averageVolume10days': 14767670,
#  'beta': None,
#  'beta3Year': None,
#  'bid': 3.8,
#  'bidSize': 3200,
#  'bookValue': 1.137,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Franklin',
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 3.74,
#  'currentRatio': 2.02,
#  'dateShortInterest': 1646006400,
#  'dayHigh': 3.85,
#  'dayLow': 3.48,
#  'debtToEquity': 5.16,
#  'dividendRate': None,
#  'dividendYield': None,
#  'earningsGrowth': None,
#  'earningsQuarterlyGrowth': None,
#  'ebitda': -635745984,
#  'ebitdaMargins': -0.46699002,
#  'enterpriseToEbitda': -1.725,
# ...

# %%
Tyme = yf.Ticker("TYME")
Tyme_info=Tyme.info
Tyme_info
# Out:
# {'52WeekChange': -0.80333334,
#  'SandP52WeekChange': 0.16005337,
#  'address1': '1 Pluckemin Way',
#  'address2': 'Suite 103',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 0.3574,
#  'askSize': 1400,
#  'averageDailyVolume10Day': 537180,
#  'averageVolume': 1030278,
#  'averageVolume10days': 537180,
#  'beta': 1.050688,
#  'beta3Year': None,
#  'bid': 0.3593,
#  'bidSize': 1000,
#  'bookValue': 0.503,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Bedminster',
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 0.3489,
#  'currentRatio': 14.039,
#  'dateShortInterest': 1646006400,
#  'dayHigh': 0.362,
#  'dayLow': 0.3427,
#  'debtToEquity': 0.055,
#  'dividendRate': None,
#  'dividendYield': None,
#  'earningsGrowth': None,
#  'earningsQuarterlyGrowth': None,
#  'ebitda': -24716020,
#  'ebitdaMargins': 0,
#  'enterpriseToEbitda': 0.566,
# ...

# %%
Tyme_share_price_data.reset_index(inplace=True)
Tyme_share_price_data.plot(x="Date", y="Open")

# %%
RNWK = yf.Ticker("RNWK")
RNWK_info=RNWK.info
RNWK_info
# Out:
# {'52WeekChange': -0.8551402,
#  'SandP52WeekChange': 0.16005337,
#  'address1': '1501 First Avenue South',
#  'address2': 'Suite 600',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 0.68,
#  'askSize': 4000,
#  'averageDailyVolume10Day': 212740,
#  'averageVolume': 229396,
#  'averageVolume10days': 212740,
#  'beta': 1.546259,
#  'beta3Year': None,
#  'bid': 0.71,
#  'bidSize': 800,
#  'bookValue': 0.975,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Seattle',
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 0.683,
#  'currentRatio': 2.253,
#  'dateShortInterest': 1646006400,
#  'dayHigh': 0.69,
#  'dayLow': 0.6021,
#  'debtToEquity': 9.578,
#  'dividendRate': None,
#  'dividendYield': None,
#  'earningsGrowth': None,
#  'earningsQuarterlyGrowth': None,
#  'ebitda': -18035000,
#  'ebitdaMargins': -0.30997,
#  'enterpriseToEbitda': -0.269,
# ...

# %%
RNWK_share_price_data = RNWK.history(period="max")
RNWK_share_price_data.reset_index(inplace=True)
RNWK_share_price_data.plot(x="Date", y="Open")

# %%
BTC = yf.Ticker("BTC")
BTC_info=BTC.info
BTC_info
# Out:
# {'52WeekChange': None,
#  'SandP52WeekChange': None,
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 102,
#  'askSize': 1800,
#  'averageDailyVolume10Day': 2418,
#  'averageVolume': 869,
#  'averageVolume10days': 2418,
#  'beta': None,
#  'beta3Year': None,
#  'bid': 0,
#  'bidSize': 800,
#  'bondHoldings': {'creditQuality': None,
#   'creditQualityCat': None,
#   'duration': None,
#   'durationCat': None,
#   'maturity': None,
#   'maturityCat': None},
#  'bondPosition': 0.94089997,
#  'bondRatings': [{'bb': 0},
#   {'aa': 0},
#   {'aaa': 0},
#   {'a': 0},
#   {'other': 0},
#   {'b': 0},
#   {'bbb': 0},
#   {'below_b': 0},
#   {'us_government': 0}],
#  'bookValue': None,
#  'cashPosition': None,
#  'category': None,
#  'circulatingSupply': None,
#  'companyOfficers': [],
#  'convertiblePosition': None,
#  'currency': 'USD',
#  'dayHigh': 99.1568,
#  'dayLow': 99.07,
#  'dividendRate': None,
#  'dividendYield': None,
# ...
